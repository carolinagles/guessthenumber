# %% [markdown]
# <p style="color: #000000; font-size: 32px; font-weight: bold; text-align: center; margin-top: 20px;">
# GUESS THE NUMBER
# </p>

# %%
"""
Guess the Number (1-1000)

- Two game modes: single player or two players.
- Three difficulty levels.
- Game history recording.
- Results visualization.

requirements:
pip install openpyxl
pip install matplotlib
"""

# %load_ext autoreload
# %autoreload 2

from modules.main_menu import main_menu

if __name__ == "__main__":
    main_menu()
# Out:
# Guess a number between 1 and 1000
#
# Main Menu
#
# 1. Single Player Game
# 2. 2 Player Game
# 3. Statistics
# 4. Exit
# Select a numeric option:  3
# Records
#
# 1. Last 20 Games
# 2. Player Performance
# 3. Percentage of Games Won or Lost
# 4. Return
# Select a numeric option:  2
# Records
#
# 1. Last 20 Games
# 2. Player Performance
# 3. Percentage of Games Won or Lost
# 4. Return
# Select a numeric option:  3
# Records
#
# 1. Last 20 Games
# 2. Player Performance
# 3. Percentage of Games Won or Lost
# 4. Return
# Select a numeric option:  1
#    Last Games
#                      Date       Name    Mode Difficulty  Attempts Result  \
# 1100  2025-10-31 01:53:18      Novak  Single     Medium         5   Lost
# 1101  2025-10-31 02:42:41  Ekaterina  Double       Hard         4   Lost
# 1102  2025-10-31 04:56:04      Mirra  Single       Hard         1   Lost
# 1103  2025-10-31 05:12:11        Iga  Double       Hard         3    Won
# 1104  2025-10-31 05:24:29  Alexander  Double       Easy         1   Lost
# 1105  2025-10-31 07:13:50     Jannik  Single       Easy         1    Won
# 1106  2025-10-31 08:35:38    Jessica  Single     Medium         4    Won
# 1107  2025-10-31 10:19:59     Amanda  Single     Medium         5   Lost
# 1108  2025-10-31 10:23:30     Taylor  Single       Hard         3    Won
# 1109  2025-10-31 10:42:04      Elena  Single       Easy         1    Won
# 1110  2025-10-31 12:35:03        Ben  Single       Easy         2   Lost
# 1111  2025-10-31 13:22:23       Coco  Single     Medium         4   Lost
# 1112  2025-10-31 14:02:19     Carlos  Single     Medium         2   Lost
# 1113  2025-10-31 15:39:04     Amanda  Single       Easy         1   Lost
# 1114  2025-10-31 16:45:44    Jasmine  Single     Medium         3   Lost
# 1115  2025-10-31 17:58:12     Carlos  Single     Medium         1    Won
# 1116  2025-10-31 19:23:12  Alexander  Single     Medium         3   Lost
# 1117  2025-10-31 22:32:17    Jessica  Single       Easy         2    Won
# 1118  2025-11-26 19:44:52     Taylor  Double       Hard         3    Won
# 1119  2025-11-26 20:05:12     Taylor  Double       Hard         3    Won
#
#      Unnamed: 6
# 1100        NaN
# 1101        NaN
# 1102        NaN
# 1103        NaN
# 1104        NaN
# 1105        NaN
# 1106        NaN
# 1107        NaN
# 1108        NaN
# 1109        NaN
# 1110        NaN
# 1111        NaN
# 1112        NaN
# 1113        NaN
# 1114        NaN
# 1115        NaN
# 1116        NaN
# 1117        NaN
# 1118        NaN
# 1119        NaN
# Records
#
# 1. Last 20 Games
# 2. Player Performance
# 3. Percentage of Games Won or Lost
# 4. Return
# Select a numeric option:  4
# Guess a number between 1 and 1000
#
# Main Menu
#
# 1. Single Player Game
# 2. 2 Player Game
# 3. Statistics
# 4. Exit
# Select a numeric option:  2
# Let's start playing!
#
# 2 Player Mode
# Choose difficulty level:
# 1. Easy → 20 attempts
# 2. Medium → 12 attempts
# 3. Hard → 5 attempts
#  123
# Please choose one of the three levels:
# Choose difficulty level:
# 1. Easy → 20 attempts
# 2. Medium → 12 attempts
# 3. Hard → 5 attempts
#  4
# Please choose one of the three levels:
# Choose difficulty level:
# 1. Easy → 20 attempts
# 2. Medium → 12 attempts
# 3. Hard → 5 attempts
#  3
# Think of the number you want the second player to guess...
# Enter a number between 1 and 1000:
#  ········
# Enter your first attempt:
# You have 5 attempts:  123
# Try with a HIGHER number
# You have 4 attempts:  345
# Try with a HIGHER number
# You have 3 attempts:  999
# Try with a LOWER number
# You have 2 attempts:  789
# Congratulations! You guessed the number!
# Save your game
#  Name of the player who guessed:  Carlos
# Guess a number between 1 and 1000
#
# Main Menu
#
# 1. Single Player Game
# 2. 2 Player Game
# 3. Statistics
# 4. Exit
# Select a numeric option:  4
# See you soon!
# Selecciona una opción númerica:  4
# Adivina un número entre 1 y 1000
#
# Menú pricipal
#
# 1. Partida modo solitario
# 2. Partido 2 jugadores
# 3. Estadística
# 4. Salir
# Selecciona una opción númerica:  2
# ¡Comenzemos a jugar!
#
# Modo 2 Jugadores
# Elige el nivel de dificultad:
# 1. Fácil → 20 intentos
# 2. Medio → 12 intentos
# 3. Difícil → 5 intentos
#  5
# Elige uno de los tres niveles:
# Elige el nivel de dificultad:
# 1. Fácil → 20 intentos
# 2. Medio → 12 intentos
# 3. Difícil → 5 intentos
#  3
# Piensa el número que quieres que adivine el segundo jugador...
# Escribe el número entre 1 y 1000:
#  ········
# Ingresa tu primer intento:
# Tienes 5 intentos:  12
# Intenta con un numero MAYOR
# Tienes 4 intentos:  534
# Intenta con un numero MENOR
# Tienes 3 intentos:  2345
# Ingresa un número entre 1 y 1000
# Tienes 3 intentos:  123
# ¡Lo lograste, adivinaste el número!
# Registra tu partida
#  Nombre de quien adivinó:  Ana
# Adivina un número entre 1 y 1000
#
# Menú pricipal
#
# 1. Partida modo solitario
# 2. Partido 2 jugadores
# 3. Estadística
# 4. Salir
# Selecciona una opción númerica:  4
# ¡Nos vemos pronto!
